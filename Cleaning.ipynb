# %%
import pandas as pd 
intern =pd.read_csv(r"C:\Users\laxmi\Documents\JUPYTER\PROJECT\Internship_Placement.csv")

# %%
intern
# Out:
#                           Timestamp                          Username  \
# 0   2025/07/10 12:36:44 AM GMT+5:30         shivanshsharm83@gmail.com
# 1   2025/07/10 12:50:59 AM GMT+5:30        shikha8894422803@gmail.com
# 2    2025/07/10 2:36:47 AM GMT+5:30        nishantsingh8560@gmail.com
# 3    2025/07/10 8:04:49 AM GMT+5:30              rupali4734@gmail.com
# 4   2025/07/10 12:35:54 PM GMT+5:30       sahilthakur1stoct@gmail.com
# 5    2025/07/10 2:37:50 PM GMT+5:30         laxmitamang5829@gmail.com
# 6    2025/07/10 3:11:06 PM GMT+5:30            gargmehak208@gmail.com
# 7    2025/07/10 3:11:22 PM GMT+5:30            swanjalrawat@gmail.com
# 8   2025/07/10 10:08:38 PM GMT+5:30            anish.ri1507@gmail.com
# 9   2025/07/10 10:14:25 PM GMT+5:30             rashijoon19@gmail.com
# 10  2025/07/10 10:21:49 PM GMT+5:30         manpreetsing611@gmail.com
# 11  2025/07/10 10:22:14 PM GMT+5:30       iamsharmalakshita@gmail.com
# ...

# %%
import numpy as np
intern.replace(['Na', 'Nan', 'N', 'NaN', np.nan], '', inplace=True)

# %%
intern
# Out:
#                           Timestamp                          Username  \
# 0   2025/07/10 12:36:44 AM GMT+5:30         shivanshsharm83@gmail.com
# 1   2025/07/10 12:50:59 AM GMT+5:30        shikha8894422803@gmail.com
# 2    2025/07/10 2:36:47 AM GMT+5:30        nishantsingh8560@gmail.com
# 3    2025/07/10 8:04:49 AM GMT+5:30              rupali4734@gmail.com
# 4   2025/07/10 12:35:54 PM GMT+5:30       sahilthakur1stoct@gmail.com
# 5    2025/07/10 2:37:50 PM GMT+5:30         laxmitamang5829@gmail.com
# 6    2025/07/10 3:11:06 PM GMT+5:30            gargmehak208@gmail.com
# 7    2025/07/10 3:11:22 PM GMT+5:30            swanjalrawat@gmail.com
# 8   2025/07/10 10:08:38 PM GMT+5:30            anish.ri1507@gmail.com
# 9   2025/07/10 10:14:25 PM GMT+5:30             rashijoon19@gmail.com
# 10  2025/07/10 10:21:49 PM GMT+5:30         manpreetsing611@gmail.com
# 11  2025/07/10 10:22:14 PM GMT+5:30       iamsharmalakshita@gmail.com
# ...

# %%
intern.isin(['Na', 'Nan', 'N', 'NaN','NA']).sum()
# Out:
# Timestamp                                                      0
# Username                                                       0
# Name                                                           0
# Which year of college are you in?                              0
# Course                                                         0
# Have you done any internship?                                  0
# How did you find the internship                                0
# How was your overall internship experience?                    0
# How satisfied were you with the learning during internship?    0
#  How was your internship experience?                           0
# Did you participate in any placement drives?                   0
# Were you selected in any placement drive?                      0
#   How did you get your placement?                              0
# How confident do you feel about getting placed                 0
# ...

# %%
intern.replace(['Na', 'Nan', 'N', 'NaN'], np.nan, inplace=True)

# %%
Unwanted_Columns = ["Timestamp", "Username", "Name"]
intern.drop(columns=Unwanted_Columns, axis=1, inplace=True)

# %%
intern.columns = intern.columns.str.strip()
intern
# Out:
#    Which year of college are you in?   Course Have you done any internship?  \
# 0                           2nd Year      MBA                           Yes
# 1                         Passed Out      MBA                            No
# 2                           2nd Year      MBA                           Yes
# 3                         Passed Out      BCA                            No
# 4                         Passed Out      BCA                           Yes
# 5                         Final Year      MCA                           Yes
# 6                           3rd Year    BTECH                           Yes
# 7                           3rd Year    BTECH                           Yes
# 8                         Passed Out      BCA                           Yes
# 9                           2nd Year      MBA                           Yes
# 10                        Passed Out      BCA                           Yes
# ...

# %%
intern["Share your placement experience in a few words."]= intern["Share your placement experience in a few words."].str.replace('Na', '')

# %%
intern
# Out:
#    Which year of college are you in?   Course Have you done any internship?  \
# 0                           2nd Year      MBA                           Yes
# 1                         Passed Out      MBA                            No
# 2                           2nd Year      MBA                           Yes
# 3                         Passed Out      BCA                            No
# 4                         Passed Out      BCA                           Yes
# 5                         Final Year      MCA                           Yes
# 6                           3rd Year    BTECH                           Yes
# 7                           3rd Year    BTECH                           Yes
# 8                         Passed Out      BCA                           Yes
# 9                           2nd Year      MBA                           Yes
# 10                        Passed Out      BCA                           Yes
# ...

# %%
intern.columns = intern.columns.str.strip()
intern
# Out:
#    Which year of college are you in?   Course Have you done any internship?  \
# 0                           2nd Year      MBA                           Yes
# 1                         Passed Out      MBA                            No
# 2                           2nd Year      MBA                           Yes
# 3                         Passed Out      BCA                            No
# 4                         Passed Out      BCA                           Yes
# 5                         Final Year      MCA                           Yes
# 6                           3rd Year    BTECH                           Yes
# 7                           3rd Year    BTECH                           Yes
# 8                         Passed Out      BCA                           Yes
# 9                           2nd Year      MBA                           Yes
# 10                        Passed Out      BCA                           Yes
# ...

# %%
new_column = { "Which year of college are you in?": "Year",
    "Have you done any internship?": "Internship_Done",
    "How did you find the internship": "Internship_Source",
    "How was your overall internship experience?": "Intern_Overall",
    "How satisfied were you with the learning during internship?": "Intern_Learn_Score",
    "How was your internship experience?": "Intern_Experience",
    "Did you participate in any placement drives?": "Placement_Attempted",
    "Were you selected in any placement drive?": "Placement_Selected",
    "How did you get your placement?": "Placement_Mode",
    "How confident do you feel about getting placed": "Placement_Confidence",
    "How was your placement experience?": "Placement_Score",
    "Share your placement experience in a few words.": "Placement_Feedback"
}
intern.rename(columns=new_column, inplace=True)
intern
# Out:
#           Year   Course    Internship_Done Internship_Source Intern_Overall  \
# 0     2nd Year      MBA                Yes              Self           Good
# 1   Passed Out      MBA                 No              Self      Excellent
# 2     2nd Year      MBA                Yes              Self           Good
# 3   Passed Out      BCA                 No              Self  Didn't do any
# 4   Passed Out      BCA                Yes          Referral           Good
# 5   Final Year      MCA                Yes              Self           Good
# 6     3rd Year    BTECH                Yes              Self           Good
# 7     3rd Year    BTECH                Yes              Self           Good
# 8   Passed Out      BCA                Yes              Self        Average
# 9     2nd Year      MBA                Yes           College           Good
# 10  Passed Out      BCA                Yes              Self           Good
# ...

# %%
# Unwanted_Columns = ["Timestamp", "Username", "Name"]
# intern_cleaned = intern.drop(Unwanted_Columns, axis = 1 , inplace = True)
# intern

# %%
intern.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 80 entries, 0 to 79
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Year                  80 non-null     object
#  1   Course                80 non-null     object
#  2   Internship_Done       80 non-null     object
#  3   Internship_Source     80 non-null     object
#  4   Intern_Overall        80 non-null     object
#  5   Intern_Learn_Score    80 non-null     object
#  6   Intern_Experience     80 non-null     object
#  7   Placement_Attempted   80 non-null     object
#  8   Placement_Selected    80 non-null     object
#  9   Placement_Mode        80 non-null     object
#  10  Placement_Confidence  80 non-null     object
#  11  Placement_Score       80 non-null     object
#  12  Placement_Feedback    80 non-null     object
# dtypes: object(13)
# memory usage: 8.3+ KB

# %%
intern.describe()
# Out:
#             Year Course Internship_Done Internship_Source Intern_Overall  \
# count         80     80              80                80             80
# unique         5     11               3                 4              5
# top     2nd Year    MCA             Yes              Self           Good
# freq          30     33              46                38             32
#
#         Intern_Learn_Score Intern_Experience       Placement_Attempted  \
# count                 80.0                80                        80
# unique                 6.0                59                         3
# top                    3.0              Good  Not yet, but planning to
# freq                  22.0                12                        29
#
#        Placement_Selected  Placement_Mode Placement_Confidence  \
# count                  80              80                   80
# unique                  3               4                    4
# ...

# %%
intern.head()
# Out:
#          Year Course Internship_Done Internship_Source Intern_Overall  \
# 0    2nd Year    MBA             Yes              Self           Good
# 1  Passed Out    MBA              No              Self      Excellent
# 2    2nd Year    MBA             Yes              Self           Good
# 3  Passed Out    BCA              No              Self  Didn't do any
# 4  Passed Out    BCA             Yes          Referral           Good
#
#   Intern_Learn_Score                                  Intern_Experience  \
# 0                4.0                                      It was Good !
# 1                5.0
# 2                4.0  Get opportunity to apply my skills and knowled...
# 3                1.0                         I didn't do any internship
# 4                5.0                                         Excellent
#
#         Placement_Attempted         Placement_Selected Placement_Mode  \
# 0  Not yet, but planning to                         No     Not Placed
# ...

# %%
intern.tail()
# Out:
#           Year Course    Internship_Done Internship_Source Intern_Overall  \
# 75  Passed Out    BBA                 No           Not yet  Didn't do any
# 76  Passed Out    BCA  Currently looking          Referral      Excellent
# 77    2nd Year    MCA                 No           Not yet  Didn't do any
# 78  Passed Out    MCA                 No           Not yet  Didn't do any
# 79  Passed Out     BA                 No           Not yet  Didn't do any
#
#    Intern_Learn_Score                                  Intern_Experience  \
# 75
# 76                5.0                                              Great
# 77                                          I don't have any internship
# 78                4.0                                            Not yet
# 79                1.0  I haven't done any internship yet so I have no...
#
#          Placement_Attempted         Placement_Selected  \
# 75                       Yes                        Yes
# ...

# %%
intern.shape
# Out:
# (80, 13)

# %%
intern.isnull().sum()
# Out:
# Year                    0
# Course                  0
# Internship_Done         0
# Internship_Source       0
# Intern_Overall          0
# Intern_Learn_Score      0
# Intern_Experience       0
# Placement_Attempted     0
# Placement_Selected      0
# Placement_Mode          0
# Placement_Confidence    0
# Placement_Score         0
# Placement_Feedback      0
# dtype: int64

# %%
intern.isnull().values.any()
# Out:
# np.False_

# %%
intern.isnull().sum().sum()
# Out:
# np.int64(0)

# %%
intern.fillna('')
# Out:
#           Year   Course    Internship_Done Internship_Source Intern_Overall  \
# 0     2nd Year      MBA                Yes              Self           Good
# 1   Passed Out      MBA                 No              Self      Excellent
# 2     2nd Year      MBA                Yes              Self           Good
# 3   Passed Out      BCA                 No              Self  Didn't do any
# 4   Passed Out      BCA                Yes          Referral           Good
# 5   Final Year      MCA                Yes              Self           Good
# 6     3rd Year    BTECH                Yes              Self           Good
# 7     3rd Year    BTECH                Yes              Self           Good
# 8   Passed Out      BCA                Yes              Self        Average
# 9     2nd Year      MBA                Yes           College           Good
# 10  Passed Out      BCA                Yes              Self           Good
# ...

# %%
intern.drop_duplicates()
intern
# Out:
#           Year   Course    Internship_Done Internship_Source Intern_Overall  \
# 0     2nd Year      MBA                Yes              Self           Good
# 1   Passed Out      MBA                 No              Self      Excellent
# 2     2nd Year      MBA                Yes              Self           Good
# 3   Passed Out      BCA                 No              Self  Didn't do any
# 4   Passed Out      BCA                Yes          Referral           Good
# 5   Final Year      MCA                Yes              Self           Good
# 6     3rd Year    BTECH                Yes              Self           Good
# 7     3rd Year    BTECH                Yes              Self           Good
# 8   Passed Out      BCA                Yes              Self        Average
# 9     2nd Year      MBA                Yes           College           Good
# 10  Passed Out      BCA                Yes              Self           Good
# ...

# %%
# pd.set_option('display.max.columns',13)
pd.set_option('display.max.rows',81)
intern
# Out:
#           Year   Course    Internship_Done Internship_Source Intern_Overall  \
# 0     2nd Year      MBA                Yes              Self           Good
# 1   Passed Out      MBA                 No              Self      Excellent
# 2     2nd Year      MBA                Yes              Self           Good
# 3   Passed Out      BCA                 No              Self  Didn't do any
# 4   Passed Out      BCA                Yes          Referral           Good
# 5   Final Year      MCA                Yes              Self           Good
# 6     3rd Year    BTECH                Yes              Self           Good
# 7     3rd Year    BTECH                Yes              Self           Good
# 8   Passed Out      BCA                Yes              Self        Average
# 9     2nd Year      MBA                Yes           College           Good
# 10  Passed Out      BCA                Yes              Self           Good
# ...

# %%
(intern== '').sum()
# Out:
# Year                     0
# Course                   0
# Internship_Done          0
# Internship_Source        0
# Intern_Overall           0
# Intern_Learn_Score       3
# Intern_Experience        7
# Placement_Attempted      0
# Placement_Selected       0
# Placement_Mode           0
# Placement_Confidence     0
# Placement_Score          3
# Placement_Feedback      12
# dtype: int64

# %%
intern["Placement_Feedback"].value_counts(dropna=False) 
#	Tells pandas not to ignore NaN values (missing values), so you can see how many blanks or nulls are there too.
# Out:
# Placement_Feedback
# ...

# %%
# First strip spaces and make lowercase for consistency
intern["Placement_Attempted"] = intern["Placement_Attempted"].astype(str).str.strip().str.lower()
intern["Placement_Attempted"] = intern["Placement_Attempted"].replace({
    'yes': 'Yes',
    'no': 'No',
    'not yet, but planning to': 'Planning',
    'planning to': 'Planning',
    'not yet': 'Planning'
})
intern
# Out:
#           Year   Course    Internship_Done Internship_Source Intern_Overall  \
# 0     2nd Year      MBA                Yes              Self           Good
# 1   Passed Out      MBA                 No              Self      Excellent
# 2     2nd Year      MBA                Yes              Self           Good
# 3   Passed Out      BCA                 No              Self  Didn't do any
# 4   Passed Out      BCA                Yes          Referral           Good
# 5   Final Year      MCA                Yes              Self           Good
# 6     3rd Year    BTECH                Yes              Self           Good
# 7     3rd Year    BTECH                Yes              Self           Good
# 8   Passed Out      BCA                Yes              Self        Average
# 9     2nd Year      MBA                Yes           College           Good
# 10  Passed Out      BCA                Yes              Self           Good
# ...

# %%
# intern["Placement_Mode "]=intern["Placement_Mode"].astype(str).str.strip()
# intern["Placement_Mode "]=intern["Placement_Mode"].replace({ 
#     'Off-Campus (Applied Online / Referral / Walk-in)': 'Off-Campus',
#     'On Campus (College Placement Drive)': 'On-Campus',
#     'Not Placed Yet': 'Not Placed'
# })
# intern

# Make sure column name has no trailing space
intern["Placement_Mode"] = intern["Placement_Mode"].astype(str).str.strip()

# Replace values
intern["Placement_Mode"] = intern["Placement_Mode"].replace({
    'Off-Campus (Applied Online / Referral / Walk-in)': 'Off-Campus',
    'On Campus (College Placement Drive)': 'On-Campus',
    'Not Placed Yet': 'Not Placed'
})

intern.head()
# Out:
#          Year Course Internship_Done Internship_Source Intern_Overall  \
# 0    2nd Year    MBA             Yes              Self           Good
# 1  Passed Out    MBA              No              Self      Excellent
# 2    2nd Year    MBA             Yes              Self           Good
# 3  Passed Out    BCA              No              Self  Didn't do any
# 4  Passed Out    BCA             Yes          Referral           Good
#
#   Intern_Learn_Score                                  Intern_Experience  \
# 0                4.0                                      It was Good !
# 1                5.0
# 2                4.0  Get opportunity to apply my skills and knowled...
# 3                1.0                         I didn't do any internship
# 4                5.0                                         Excellent
#
#   Placement_Attempted         Placement_Selected Placement_Mode  \
# 0            Planning                         No     Not Placed
# ...

# %%
intern.columns = intern.columns.str.strip()

# %%
intern
# Out:
#           Year   Course    Internship_Done Internship_Source Intern_Overall  \
# 0     2nd Year      MBA                Yes              Self           Good
# 1   Passed Out      MBA                 No              Self      Excellent
# 2     2nd Year      MBA                Yes              Self           Good
# 3   Passed Out      BCA                 No              Self  Didn't do any
# 4   Passed Out      BCA                Yes          Referral           Good
# 5   Final Year      MCA                Yes              Self           Good
# 6     3rd Year    BTECH                Yes              Self           Good
# 7     3rd Year    BTECH                Yes              Self           Good
# 8   Passed Out      BCA                Yes              Self        Average
# 9     2nd Year      MBA                Yes           College           Good
# 10  Passed Out      BCA                Yes              Self           Good
# ...

# %%
intern.columns = intern.columns.str.strip()  # removes extra spaces
print(intern.columns.tolist())
# Out:
# ['Year', 'Course', 'Internship_Done', 'Internship_Source', 'Intern_Overall', 'Intern_Learn_Score', 'Intern_Experience', 'Placement_Attempted', 'Placement_Selected', 'Placement_Mode', 'Placement_Confidence', 'Placement_Score', 'Placement_Feedback']

# %%
intern.columns = intern.columns.str.strip()

# %%
print(intern.columns.tolist())
# Out:
# ['Year', 'Course', 'Internship_Done', 'Internship_Source', 'Intern_Overall', 'Intern_Learn_Score', 'Intern_Experience', 'Placement_Attempted', 'Placement_Selected', 'Placement_Mode', 'Placement_Confidence', 'Placement_Score', 'Placement_Feedback']

# %%
intern["Placement_Mode"] = intern["Placement_Mode"].astype(str)
intern
# Out:
#           Year   Course    Internship_Done Internship_Source Intern_Overall  \
# 0     2nd Year      MBA                Yes              Self           Good
# 1   Passed Out      MBA                 No              Self      Excellent
# 2     2nd Year      MBA                Yes              Self           Good
# 3   Passed Out      BCA                 No              Self  Didn't do any
# 4   Passed Out      BCA                Yes          Referral           Good
# 5   Final Year      MCA                Yes              Self           Good
# 6     3rd Year    BTECH                Yes              Self           Good
# 7     3rd Year    BTECH                Yes              Self           Good
# 8   Passed Out      BCA                Yes              Self        Average
# 9     2nd Year      MBA                Yes           College           Good
# 10  Passed Out      BCA                Yes              Self           Good
# ...

# %%
# Replace with simplified versions
intern["Placement_Mode"] = intern["Placement_Mode"].replace({
    'Off-Campus (Applied Online / Referral / Walk-in)': 'Off-Campus',
    'On Campus (College Placement Drive)': 'On-Campus',
    'Not Placed Yet': 'Not Placed'
})

# %%
intern
# Out:
#           Year   Course    Internship_Done Internship_Source Intern_Overall  \
# 0     2nd Year      MBA                Yes              Self           Good
# 1   Passed Out      MBA                 No              Self      Excellent
# 2     2nd Year      MBA                Yes              Self           Good
# 3   Passed Out      BCA                 No              Self  Didn't do any
# 4   Passed Out      BCA                Yes          Referral           Good
# 5   Final Year      MCA                Yes              Self           Good
# 6     3rd Year    BTECH                Yes              Self           Good
# 7     3rd Year    BTECH                Yes              Self           Good
# 8   Passed Out      BCA                Yes              Self        Average
# 9     2nd Year      MBA                Yes           College           Good
# 10  Passed Out      BCA                Yes              Self           Good
# ...

# %%
print(intern.columns.tolist())
# Out:
# ['Year', 'Course', 'Internship_Done', 'Internship_Source', 'Intern_Overall', 'Intern_Learn_Score', 'Intern_Experience', 'Placement_Attempted', 'Placement_Selected', 'Placement_Mode', 'Placement_Confidence', 'Placement_Score', 'Placement_Feedback']

# %%
intern.rename(columns=lambda x: x.strip(), inplace=True)

# %%
intern = intern.loc[:, ~intern.columns.duplicated(keep='last')]

# %%
intern["Placement_Mode"]
# Out:
# 0     Not Placed
# 1     Not Placed
# 2     Not Placed
# 3     Not Placed
# 4     Not Placed
# 5     Not Placed
# 6     Not Placed
# 7     Not Placed
# 8     Off-Campus
# 9     Not Placed
# 10    Off-Campus
# 11    Not Placed
# 12    Not Placed
# 13    Not Placed
# 14    Not Placed
# 15    Not Placed
# 16    Not Placed
# 17     On-Campus
# 18    Not Placed
# 19     On-Campus
# 20    Not Placed
# 21     On-Campus
# 22    Not Placed
# 23    Not Placed
# 24    Not Placed
# 25    Not Placed
# 26    Off-Campus
# 27    Not Placed
# 28    Not Placed
# 29    Not Placed
# 30    Not Placed
# 31    Not Placed
# 32    Not Placed
# 33    Not Placed
# 34    Not Placed
# 35    Not Placed
# 36    Not Placed
# 37    Off-Campus
# 38    Not Placed
# 39    Not Placed
# 40    Off-Campus
# 41     On-Campus
# 42    Off-Campus
# 43    Not Placed
# 44    Not Placed
# 45    Off-Campus
# 46    Not Placed
# 47     On-Campus
# 48    Off-Campus
# 49    Not Placed
# 50     On-Campus
# 51    Not Placed
# ...

# %%
type(intern["Placement_Mode"])         # Should be: <class 'pandas.core.series.Series'>
type(intern[["Placement_Mode"]])       # Is: <class 'pandas.core.frame.DataFrame'>
# Out:
# pandas.core.frame.DataFrame

# %%
intern
# Out:
#           Year   Course    Internship_Done Internship_Source Intern_Overall  \
# 0     2nd Year      MBA                Yes              Self           Good
# 1   Passed Out      MBA                 No              Self      Excellent
# 2     2nd Year      MBA                Yes              Self           Good
# 3   Passed Out      BCA                 No              Self  Didn't do any
# 4   Passed Out      BCA                Yes          Referral           Good
# 5   Final Year      MCA                Yes              Self           Good
# 6     3rd Year    BTECH                Yes              Self           Good
# 7     3rd Year    BTECH                Yes              Self           Good
# 8   Passed Out      BCA                Yes              Self        Average
# 9     2nd Year      MBA                Yes           College           Good
# 10  Passed Out      BCA                Yes              Self           Good
# ...

# %%
intern["Placement_Selected"] = intern["Placement_Selected"].str.lower().str.strip()
intern["Placement_Selected"] = intern["Placement_Selected"].replace({
    "yes": "Yes",
    "no": "No",
    "still waiting for results": "Waiting"
})
intern
# Out:
#           Year   Course    Internship_Done Internship_Source Intern_Overall  \
# 0     2nd Year      MBA                Yes              Self           Good
# 1   Passed Out      MBA                 No              Self      Excellent
# 2     2nd Year      MBA                Yes              Self           Good
# 3   Passed Out      BCA                 No              Self  Didn't do any
# 4   Passed Out      BCA                Yes          Referral           Good
# 5   Final Year      MCA                Yes              Self           Good
# 6     3rd Year    BTECH                Yes              Self           Good
# 7     3rd Year    BTECH                Yes              Self           Good
# 8   Passed Out      BCA                Yes              Self        Average
# 9     2nd Year      MBA                Yes           College           Good
# 10  Passed Out      BCA                Yes              Self           Good
# ...

# %%
intern["Internship_Done"] = intern["Internship_Done"].replace({
    "Currently looking": "Looking"})
intern
# Out:
#           Year   Course Internship_Done Internship_Source Intern_Overall  \
# 0     2nd Year      MBA             Yes              Self           Good
# 1   Passed Out      MBA              No              Self      Excellent
# 2     2nd Year      MBA             Yes              Self           Good
# 3   Passed Out      BCA              No              Self  Didn't do any
# 4   Passed Out      BCA             Yes          Referral           Good
# 5   Final Year      MCA             Yes              Self           Good
# 6     3rd Year    BTECH             Yes              Self           Good
# 7     3rd Year    BTECH             Yes              Self           Good
# 8   Passed Out      BCA             Yes              Self        Average
# 9     2nd Year      MBA             Yes           College           Good
# 10  Passed Out      BCA             Yes              Self           Good
# 11    2nd Year      BBA             Yes              Self      Excellent
# ...

# %%
placement_by_course = intern.groupby(['Course', 'Placement_Selected']).size().unstack(fill_value=0)
print(placement_by_course)
# Out:
# Placement_Selected  No  Waiting  Yes
# Course
# B.ARCH               1        0    0
# BA                   1        0    0
# BBA                  6        1    1
# BCA                  6        4    6
# BSC                  1        0    0
# BSC CS               0        1    0
# BTECH                6        0    2
# DIPLOMA              1        0    0
# LAW                  0        1    0
# MBA                  6        1    2
# MCA                 25        4    4

# %%
intern["Placement_Selected"].value_counts()
# Out:
# Placement_Selected
# No         53
# Yes        15
# Waiting    12
# Name: count, dtype: int64

# %%
print(intern.columns.tolist())
# Out:
# ['Year', 'Course', 'Internship_Done', 'Internship_Source', 'Intern_Overall', 'Intern_Learn_Score', 'Intern_Experience', 'Placement_Attempted', 'Placement_Selected', 'Placement_Mode', 'Placement_Confidence', 'Placement_Score', 'Placement_Feedback']

# %%
print(intern.columns[intern.columns.duplicated()])
# Out:
# Index([], dtype='object')

# %%
intern["Placement_Mode"].value_counts()
# Out:
# Placement_Mode
# Not Placed    57
# Off-Campus    15
# On-Campus      8
# Name: count, dtype: int64

# %%
duplicates = intern.columns[intern.columns.duplicated()]
print("Duplicate columns:", duplicates.tolist())
# Out:
# Duplicate columns: []

# %%
intern = intern.loc[:, ~intern.columns.duplicated()]
intern
# Out:
#           Year   Course Internship_Done Internship_Source Intern_Overall  \
# 0     2nd Year      MBA             Yes              Self           Good
# 1   Passed Out      MBA              No              Self      Excellent
# 2     2nd Year      MBA             Yes              Self           Good
# 3   Passed Out      BCA              No              Self  Didn't do any
# 4   Passed Out      BCA             Yes          Referral           Good
# 5   Final Year      MCA             Yes              Self           Good
# 6     3rd Year    BTECH             Yes              Self           Good
# 7     3rd Year    BTECH             Yes              Self           Good
# 8   Passed Out      BCA             Yes              Self        Average
# 9     2nd Year      MBA             Yes           College           Good
# 10  Passed Out      BCA             Yes              Self           Good
# 11    2nd Year      BBA             Yes              Self      Excellent
# ...

# %%
intern["Course"] = intern["Course"].replace("Nikita", "BBA")
intern
# Out:
#           Year   Course Internship_Done Internship_Source Intern_Overall  \
# 0     2nd Year      MBA             Yes              Self           Good
# 1   Passed Out      MBA              No              Self      Excellent
# 2     2nd Year      MBA             Yes              Self           Good
# 3   Passed Out      BCA              No              Self  Didn't do any
# 4   Passed Out      BCA             Yes          Referral           Good
# 5   Final Year      MCA             Yes              Self           Good
# 6     3rd Year    BTECH             Yes              Self           Good
# 7     3rd Year    BTECH             Yes              Self           Good
# 8   Passed Out      BCA             Yes              Self        Average
# 9     2nd Year      MBA             Yes           College           Good
# 10  Passed Out      BCA             Yes              Self           Good
# 11    2nd Year      BBA             Yes              Self      Excellent
# ...

# %%
intern["Course"] = intern["Course"].replace("Mca", "MCA")
intern["Course"] = intern["Course"].replace("Bca", "BCA")
intern["Course"] = intern["Course"].replace("BSCCS", "BSC_CS")

# %%
intern.groupby(["Course", "Internship_Done"]).size()
# Out:
# Course   Internship_Done
# B.ARCH   Yes                 1
# BA       No                  1
# BBA      Looking             1
#          No                  6
#          Yes                 1
# BCA      Looking             4
#          No                  5
#          Yes                 7
# BSC      No                  1
# BSC CS   Looking             1
# BTECH    No                  1
#          Yes                 7
# DIPLOMA  Yes                 1
# LAW      No                  1
# MBA      No                  1
#          Yes                 8
# MCA      Looking             7
#          No                  5
#          Yes                21
# dtype: int64

# %%
intern["Internship_Done"].value_counts()
# Out:
# Internship_Done
# Yes        46
# No         21
# Looking    13
# Name: count, dtype: int64

# %%
intern["Internship_Source"].unique()
# Out:
# array(['Self', 'Referral', 'College', 'Not yet'], dtype=object)

# %%
intern.groupby(["Course", "Internship_Source"]).size()
# Out:
# Course   Internship_Source
# B.ARCH   Self                  1
# BA       Not yet               1
# BBA      Not yet               6
#          Referral              1
#          Self                  1
# BCA      College               1
#          Not yet               5
#          Referral              4
#          Self                  6
# BSC      Self                  1
# BSC CS   Self                  1
# BTECH    College               3
#          Self                  5
# DIPLOMA  College               1
# LAW      Not yet               1
# MBA      College               2
#          Referral              1
#          Self                  6
# MCA      College               7
#          Not yet               8
#          Referral              1
#          Self                 17
# dtype: int64

# %%
intern["Internship_Source"].value_counts()
# Out:
# Internship_Source
# Self        38
# Not yet     21
# College     14
# Referral     7
# Name: count, dtype: int64

# %%
intern.rename(columns={"Intern_Overall": "Internship_Experience"}, inplace=True)

# %%
intern
# Out:
#           Year   Course Internship_Done Internship_Source  \
# 0     2nd Year      MBA             Yes              Self
# 1   Passed Out      MBA              No              Self
# 2     2nd Year      MBA             Yes              Self
# 3   Passed Out      BCA              No              Self
# 4   Passed Out      BCA             Yes          Referral
# 5   Final Year      MCA             Yes              Self
# 6     3rd Year    BTECH             Yes              Self
# 7     3rd Year    BTECH             Yes              Self
# 8   Passed Out      BCA             Yes              Self
# 9     2nd Year      MBA             Yes           College
# 10  Passed Out      BCA             Yes              Self
# 11    2nd Year      BBA             Yes              Self
# 12    2nd Year      MCA             Yes           College
# 13  Passed Out      MCA              No              Self
# 14    2nd Year      MBA             Yes              Self
# ...

# %%
experience_counts = intern["Internship_Experience"].value_counts()
print(experience_counts)
# Out:
# Internship_Experience
# Good             32
# Didn't do any    27
# Excellent        10
# Average          10
# Poor              1
# Name: count, dtype: int64

# %%
intern["Intern_Learn_Score"].value_counts()
# Out:
# Intern_Learn_Score
# 3.0    22
# 5.0    20
# 1.0    17
# 4.0    16
#         3
# 2.0     2
# Name: count, dtype: int64

# %%
rating_map = {
    5.0: "Excellent",
    4.0: "Good",
    3.0: "Average",
    2.0: "Below Average",
    1.0: "Poor"
}

# Convert column to float if it's not already
intern["Intern_Learn_Score"] = pd.to_numeric(intern["Intern_Learn_Score"], errors='coerce')

# Apply the mapping
intern["Intern_Rating_Label"] = intern["Intern_Learn_Score"].map(rating_map)

# %%
intern["Intern_Rating_Label"].value_counts()
# Out:
# Intern_Rating_Label
# Average          22
# Excellent        20
# Poor             17
# Good             16
# Below Average     2
# Name: count, dtype: int64

# %%
intern
# Out:
#           Year   Course Internship_Done Internship_Source  \
# 0     2nd Year      MBA             Yes              Self
# 1   Passed Out      MBA              No              Self
# 2     2nd Year      MBA             Yes              Self
# 3   Passed Out      BCA              No              Self
# 4   Passed Out      BCA             Yes          Referral
# 5   Final Year      MCA             Yes              Self
# 6     3rd Year    BTECH             Yes              Self
# 7     3rd Year    BTECH             Yes              Self
# 8   Passed Out      BCA             Yes              Self
# 9     2nd Year      MBA             Yes           College
# 10  Passed Out      BCA             Yes              Self
# 11    2nd Year      BBA             Yes              Self
# 12    2nd Year      MCA             Yes           College
# 13  Passed Out      MCA              No              Self
# 14    2nd Year      MBA             Yes              Self
# ...

# %%
# intern.drop("Rating_Label",axis = 1, inplace = True)
#  intern

# %%
intern = intern.replace(0, "")

# %%
intern["Placement_Score"].value_counts()
# Out:
# Placement_Score
# 1.0    30
# 5.0    19
# 3.0    16
# 4.0     9
# 2.0     3
#         3
# Name: count, dtype: int64

# %%
rating_map = {
    5.0: "Excellent",
    4.0: "Good",
    3.0: "Average",
    2.0: "Below Average",
    1.0: "Poor"
}

# Convert column to float if it's not already
intern["Intern_Learn_Score"] = pd.to_numeric(intern["Intern_Learn_Score"], errors='coerce')

# Apply the mapping
intern["Placement _rating_Label"] = intern["Placement_Score"].map(rating_map)

# %%
intern
# Out:
#           Year   Course Internship_Done Internship_Source  \
# 0     2nd Year      MBA             Yes              Self
# 1   Passed Out      MBA              No              Self
# 2     2nd Year      MBA             Yes              Self
# 3   Passed Out      BCA              No              Self
# 4   Passed Out      BCA             Yes          Referral
# 5   Final Year      MCA             Yes              Self
# 6     3rd Year    BTECH             Yes              Self
# 7     3rd Year    BTECH             Yes              Self
# 8   Passed Out      BCA             Yes              Self
# 9     2nd Year      MBA             Yes           College
# 10  Passed Out      BCA             Yes              Self
# 11    2nd Year      BBA             Yes              Self
# 12    2nd Year      MCA             Yes           College
# 13  Passed Out      MCA              No              Self
# 14    2nd Year      MBA             Yes              Self
# ...

# %%
intern.drop("Intern_Rating_Label",axis = 1, inplace = True)
intern
# Out:
#           Year   Course Internship_Done Internship_Source  \
# 0     2nd Year      MBA             Yes              Self
# 1   Passed Out      MBA              No              Self
# 2     2nd Year      MBA             Yes              Self
# 3   Passed Out      BCA              No              Self
# 4   Passed Out      BCA             Yes          Referral
# 5   Final Year      MCA             Yes              Self
# 6     3rd Year    BTECH             Yes              Self
# 7     3rd Year    BTECH             Yes              Self
# 8   Passed Out      BCA             Yes              Self
# 9     2nd Year      MBA             Yes           College
# 10  Passed Out      BCA             Yes              Self
# 11    2nd Year      BBA             Yes              Self
# 12    2nd Year      MCA             Yes           College
# 13  Passed Out      MCA              No              Self
# 14    2nd Year      MBA             Yes              Self
# ...

# %%
intern.rename(columns={"Intern_rating_Label": "Intern_Learn_Label"}, inplace=True)
intern
# Out:
#           Year   Course Internship_Done Internship_Source  \
# 0     2nd Year      MBA             Yes              Self
# 1   Passed Out      MBA              No              Self
# 2     2nd Year      MBA             Yes              Self
# 3   Passed Out      BCA              No              Self
# 4   Passed Out      BCA             Yes          Referral
# 5   Final Year      MCA             Yes              Self
# 6     3rd Year    BTECH             Yes              Self
# 7     3rd Year    BTECH             Yes              Self
# 8   Passed Out      BCA             Yes              Self
# 9     2nd Year      MBA             Yes           College
# 10  Passed Out      BCA             Yes              Self
# 11    2nd Year      BBA             Yes              Self
# 12    2nd Year      MCA             Yes           College
# 13  Passed Out      MCA              No              Self
# 14    2nd Year      MBA             Yes              Self
# ...

# %%
intern.to_csv('Final_cleaning.csv', index = False)

# %%
intern.replace(['Na', 'Nan', 'N', 'NaN', np.nan], '', inplace=True)

# %%
intern
# Out:
#           Year   Course Internship_Done Internship_Source  \
# 0     2nd Year      MBA             Yes              Self
# 1   Passed Out      MBA              No              Self
# 2     2nd Year      MBA             Yes              Self
# 3   Passed Out      BCA              No              Self
# 4   Passed Out      BCA             Yes          Referral
# 5   Final Year      MCA             Yes              Self
# 6     3rd Year    BTECH             Yes              Self
# 7     3rd Year    BTECH             Yes              Self
# 8   Passed Out      BCA             Yes              Self
# 9     2nd Year      MBA             Yes           College
# 10  Passed Out      BCA             Yes              Self
# 11    2nd Year      BBA             Yes              Self
# 12    2nd Year      MCA             Yes           College
# 13  Passed Out      MCA              No              Self
# 14    2nd Year      MBA             Yes              Self
# ...

# %%
intern.drop(columns = "Placement_Feedback")
# Out:
#           Year   Course Internship_Done Internship_Source  \
# 0     2nd Year      MBA             Yes              Self
# 1   Passed Out      MBA              No              Self
# 2     2nd Year      MBA             Yes              Self
# 3   Passed Out      BCA              No              Self
# 4   Passed Out      BCA             Yes          Referral
# 5   Final Year      MCA             Yes              Self
# 6     3rd Year    BTECH             Yes              Self
# 7     3rd Year    BTECH             Yes              Self
# 8   Passed Out      BCA             Yes              Self
# 9     2nd Year      MBA             Yes           College
# 10  Passed Out      BCA             Yes              Self
# 11    2nd Year      BBA             Yes              Self
# 12    2nd Year      MCA             Yes           College
# 13  Passed Out      MCA              No              Self
# 14    2nd Year      MBA             Yes              Self
# ...

# %%
(intern == 0).any().any()
# Out:
# np.False_

# %%
intern
# Out:
#           Year   Course Internship_Done Internship_Source  \
# 0     2nd Year      MBA             Yes              Self
# 1   Passed Out      MBA              No              Self
# 2     2nd Year      MBA             Yes              Self
# 3   Passed Out      BCA              No              Self
# 4   Passed Out      BCA             Yes          Referral
# 5   Final Year      MCA             Yes              Self
# 6     3rd Year    BTECH             Yes              Self
# 7     3rd Year    BTECH             Yes              Self
# 8   Passed Out      BCA             Yes              Self
# 9     2nd Year      MBA             Yes           College
# 10  Passed Out      BCA             Yes              Self
# 11    2nd Year      BBA             Yes              Self
# 12    2nd Year      MCA             Yes           College
# 13  Passed Out      MCA              No              Self
# 14    2nd Year      MBA             Yes              Self
# ...
